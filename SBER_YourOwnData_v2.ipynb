# %% [markdown]
# # DenoiSeg : SBER
# This is a notebook in which DenoiSeg should be trained.

# %% [markdown]
# ## Importing libraries

# %%
# Here we are just importing some libraries which are needed to run this notebook.

import warnings
warnings.filterwarnings('ignore')

import numpy as np
from matplotlib import pyplot as plt
from scipy import ndimage


from denoiseg.models import DenoiSeg, DenoiSegConfig

from denoiseg.utils.data_util import *
from denoiseg.utils.misc_utils import combine_train_test_data, shuffle_train_data, augment_data
from denoiseg.utils.seg_utils import *
from denoiseg.utils.compute_precision_threshold import measure_precision, compute_labels
from denoiseg.utils.denoiseg_data_preprocessing import generate_patches_from_list

from csbdeep.utils import plot_history
from tifffile import imread, imsave
from glob import glob


import urllib
import os
import zipfile
# Out:
# 2023-07-21 16:17:43.952953: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-21 16:17:44.006007: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-21 16:17:44.486237: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-21 16:17:44.490778: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-21 16:17:46.572915: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# This is simple plot function for plotting two patches

def plot(i, img, lbl, mode):
    img_, lbl_ = img[i], lbl[i]
    plt.figure(figsize=(16,10))
    plt.subplot(121); plt.imshow(img_,cmap='gray');   plt.axis('off'); plt.title(f'Raw image {mode}')
    plt.subplot(122); plt.imshow(lbl_);   plt.axis('off'); plt.title(f'Mask image {mode}')
    plt.show()
    print(np.min(img_),np.max(img_))
    print(np.min(lbl_),np.max(lbl_))

# %% [markdown]
# ## Downloading and  Data Loading
# We download a dataset consisting of noisy flywing images. The downloaded data creates a folder `MyData` and extracts within it three subfolders `train`, `val` and `test`. These folders have subfolders `raw` and `gt`. In `train/raw` folder, there are `1428` raw images and only the first `5` of raw images have ground truth annotations in folder `train/gt`. Similarly, in `val/raw` folder, there are `252` raw images and only the first `2` of raw images have ground truth annotations in folder `val/gt`. The `test` folder only has `raw` subfolder since these are the images we want denoised and segmented outputs for.

# %% [markdown]
# ## Initialize dirs and globals
# Here we initialize all your directories where your raw images and labels are stored. Also here we define some global variables that are need for creating dataset of patches from our full images. Don't forget to change ddefaults

# %%
dataset_name = 'g123'
default_dir = './data/patches/'
img_dir = './data/b2u_g123_first/'
label_dir = './data/cvat_g123/'

ext_img = os.path.splitext(os.listdir(img_dir)[0])[1]
ext_lbl = os.path.splitext(os.listdir(label_dir)[0])[1]

imgs_dir = os.path.abspath(img_dir)
lbls_dir = os.path.abspath(label_dir)

len_test = 3
len_val = 30
patch_size = (768, 768)
max_patches = 100

os.makedirs(default_dir, exist_ok=True)
os.makedirs(label_dir, exist_ok=True)

# %% [markdown]
# ## Fit colors for classes
# Here we fit colors for our labeled images. We want to change our colors from RGB to B as original colors are distorted.
#
# Firstly, we define a directory for image that conctains all classes we need to label. -> change image_4cl_dir
# Secondly, we get mask colors - all our classes - and print them

# %%
image_4cl_dir = './data/cvat_g123'
test_image = cv2.imread(os.path.join(image_4cl_dir, os.listdir(image_4cl_dir)[1]),0)

mask_colors = np.unique(test_image)
num_classes = len(mask_colors)
print(f'mask colors: {mask_colors}')
print(f'Number of classes {num_classes}')
# Out:
# mask colors: [  0  81 113 205]
# Number of classes 4

# %% [markdown]
# Then we define a dict rgb_to_index, which contains new values for each of classes from our mask_colors
#
# !! Dont forget to make an extra item if you have more classes

# %%
rgb_to_index = {
    mask_colors[0]:0,
    mask_colors[3]:1,
    mask_colors[2]:2,
    mask_colors[1]:3,}

# %% [markdown]
# Here we plot the image and check if the display of image is correct.

# %% [markdown]
# #### !!Dont forget to change rgb_to_index according to the displayed colors and index_to_legend

# %%
# Legend, which contains definitions to all our new values of classes
# !! Dont forget to make an extra item if you have more classes
index_to_legend = {
    0 : 'background',
    1 : 'holes',
    2 : 'borders',
    3 : 'bad_structures'
}

#Проверка, что для всех цветов из маски сопоставили индекс
if len(mask_colors) != len(rgb_to_index):
    raise Exception(f'len(mask_colors) != len(rgb_to_legend), {len(mask_colors)} != {len(rgb_to_legend)}')


mask = np.zeros_like(test_image)

for i in rgb_to_index.keys():
    mask[test_image == i] = rgb_to_index[i]


mask_cmap = matplotlib.colors.ListedColormap(['black', 'blue', 'red', 'yellow'])
print('Check that colors show according to legend:\n"background" : "black",\n"holes" : "blue",\n"borders" : "red",\n"bad_structures" : "yellow"')
plt.imshow(mask, cmap=mask_cmap )
# Out:
# Check that colors show according to legend:
# "background" : "black",
# "holes" : "blue",
# "borders" : "red",
# "bad_structures" : "yellow"

# %% [markdown]
# ## Make dataset
# Here we create our dataset of patches and plot some images to check if images and labels match

# %%
train_images, available_train_masks, val_images, available_val_masks = make_dataset(imgs_dir, lbls_dir, ext_img, ext_lbl, rgb_to_index, patch_size, max_patches, len_val)
# Out:
# - training:       1470
# - validation:      30

# %%
plot(120, train_images, available_train_masks, 'train')
plot(0, val_images, available_val_masks, 'train while loading')
# Out:
# 0 147
# 0 2
# 0 152
# 0 2

# %% [markdown]
# ### Create zero images for missing masks

# %% [markdown]
# Here we create zero images for those training and validation images for which segmentation masks are not present. Then we use these zero images along with the images for which segmentation annotations are available for training the DenoiSeg network.

# %%
blank_images_train = np.zeros((len(train_images)-len(available_train_masks), available_train_masks[0].shape[0], available_train_masks[0].shape[1]))
blank_images_val = np.zeros((len(val_images)-len(available_val_masks), available_val_masks[0].shape[0], available_val_masks[0].shape[1]))
blank_images_train = blank_images_train.astype("uint16")
blank_images_val = blank_images_val.astype("uint16")

train_masks = np.concatenate((available_train_masks,blank_images_train), axis = 0)
val_masks = np.concatenate((available_val_masks,blank_images_val), axis = 0)

plot(400, train_images, train_masks, 'train')
# Out:
# 0 141
# 0 0

# %% [markdown]
# ## Data Preprocessing
# We do some necessary data preprocessing in the cell below such as one-hot encoding training data to extract foreground, background, border and bad structures classes from our training and validation masks.

# %%
def onehot_encoding(lbl, n_classes=4, dtype=np.uint32):
    """ n_classes will be determined by max lbl value if its value is None """
    onehot = np.zeros((*lbl.shape, n_classes), dtype=dtype)
    for i in range(n_classes):
        onehot[lbl == i, ..., i] = 1
    return onehot

# %%
num_classes
# Out:
# 4

# %%
# Here we add the channel dimension to our input images.
# Dimensionality for training has to be 'SYXC' (Sample, Y-Dimension, X-Dimension, Channel)

X_final = np.expand_dims(train_images, 3)
print('processing y final')

Y_final = np.zeros((len(train_masks), *train_masks[0].shape, num_classes))

for i in range(len(train_masks)):
    Y_final[i, ...] =  onehot_encoding(train_masks[i], n_classes=num_classes)

print('processing x val')
X_val_final = np.expand_dims(val_images, 3)

print('processing y val')
Y_val_final = np.zeros((len(val_masks), *val_masks[0].shape, num_classes))

for i in range(len(val_masks)):
    Y_val_final[i] =  onehot_encoding(val_masks[i], n_classes=num_classes)

print("Shape of X:     {}".format(X_final.shape))
print("Shape of Y:     {}".format(Y_final.shape))
print("Shape of X_val: {}".format(X_val_final.shape))
print("Shape of Y_val: {}".format(Y_val_final.shape))

# %% [markdown]
# Next we look at a single sample. In the first column we show the input image, in the second column the background segmentation, in the third column the foreground segmentation and in the last column the border segmentation.
#
# With the parameter `sample` you can choose different training patches. You will notice that not all of them have a segmentation ground truth.

# %%
sample = 100
plt.figure(figsize=(20,5))
plt.subplot(1,5,1)
plt.imshow(X_final[sample,...,0])
plt.axis('off')
plt.title('Raw training image')
plt.subplot(1,5,2)
plt.imshow(Y_final[sample,...,0], vmin=0, vmax=1, interpolation='nearest')
plt.axis('off')
plt.title('1-hot encoded background')
plt.subplot(1,5,3)
plt.imshow(Y_final[sample,...,1], vmin=0, vmax=1, interpolation='nearest')
plt.axis('off')
plt.title('1-hot encoded holes')
plt.subplot(1,5,4)
plt.imshow(Y_final[sample,...,2], vmin=0, vmax=1, interpolation='nearest')
plt.axis('off')
plt.title('1-hot encoded border')
plt.subplot(1,5,5)
plt.imshow(Y_final[sample,...,3], vmin=0, vmax=1, interpolation='nearest')
plt.axis('off')
plt.title('1-hot encoded bad structures')
# Out:
# (-0.5, 767.5, 767.5, -0.5)

# %% [markdown]
# ### Configure network parameters

# %%
train_batch_size = 3
train_steps_per_epoch = len(X_final)//train_batch_size

# %%
### In the next cell, you can choose how much relative importance (weight) to assign to denoising 
### and segmentation tasks by choosing appropriate value for denoiseg_alpha (between 0 and 1; with 0 being
### only segmentation and 1 being only denoising. Here we choose denoiseg_alpha = 0.5)

# %%
conf = DenoiSegConfig(X_final, unet_kern_size=3, n_channel_in=1, n_channel_out=5, relative_weights = [1.0,1.0,5.0],
                      train_steps_per_epoch=train_steps_per_epoch, train_epochs=120, 
                      batch_norm=True, train_batch_size=train_batch_size, unet_n_first = 32, 
                      unet_n_depth=4, denoiseg_alpha=0.5, train_tensorboard=False)

vars(conf)
# Out:
# {'means': ['74.29254553995014'],
#  'stds': ['17.87368322577132'],
#  'n_dim': 2,
#  'axes': 'YXC',
#  'n_channel_in': 1,
#  'n_channel_out': 5,
#  'train_loss': 'denoiseg',
#  'unet_n_depth': 4,
#  'relative_weights': [1.0, 1.0, 5.0],
#  'unet_kern_size': 3,
#  'unet_n_first': 32,
#  'unet_last_activation': 'linear',
#  'probabilistic': False,
#  'unet_residual': False,
#  'unet_input_shape': (None, None, 1),
#  'train_epochs': 120,
#  'train_steps_per_epoch': 10,
#  'train_learning_rate': 0.0004,
#  'train_batch_size': 128,
#  'train_tensorboard': False,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'train_reduce_lr': {'monitor': 'val_loss', 'factor': 0.5, 'patience': 10},
#  'batch_norm': True,
#  'n2v_perc_pix': 1.5,
#  'n2v_patch_shape': (64, 64),
#  'n2v_manipulator': 'uniform_withCP',
#  'n2v_neighborhood_radius': 5,
#  'denoiseg_alpha': 0.5}

# %%
model_name = 'DenoiSeg_g123'
basedir = 'models'
model = DenoiSeg(conf, model_name, basedir)
# Out:
# 2023-07-20 18:40:35.315910: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10367 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1
# 2023-07-20 18:40:35.316807: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9450 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:03:00.0, compute capability: 6.1

# %%
history = model.train(X_final, Y_final, (X_val_final, Y_val_final))
# Out:
# 61 blind-spots will be generated per training patch of size (64, 64).
# Preparing validation data: 100%|██████████| 30/30 [00:07<00:00,  4.13it/s]
# Epoch 1/120
# 2023-07-20 18:40:54.081621: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 history = model.train(X_final, Y_final, (X_val_final, Y_val_final))
#
# File ~/SSD/vscode/DenoiSeg/denoiseg/models/denoiseg_standard.py:219, in DenoiSeg.train(self, X, Y, validation_data, epochs, steps_per_epoch)
#     213 validation_Y = np.concatenate((validation_Y, validation_data[1]), axis=-1)
#     215 # validation_data = DenoiSeg_ValDataWrapper(X=validation_X,
#     216 #                                           Y=validation_Y,
#     217 #                                           batch_size=self.config.train_batch_size)
# --> 219 history = self.keras_model.fit(training_data, validation_data=(validation_X, validation_Y),
#     220                                          epochs=epochs, steps_per_epoch=steps_per_epoch,
#     221                                          callbacks=self.callbacks, verbose=1)
#     223 if self.basedir is not None:
#     224     self.keras_model.save_weights(str(self.logdir / 'weights_last.h5'))
#
# File ~/SSD/miniconda3/envs/denoiseg/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /tmp/__autograph_generated_filedaj_s42c.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File /tmp/__autograph_generated_filefydnm62v.py:14, in outer_factory.<locals>.inner_factory.<locals>.tf__denoiseg(y_true, y_pred)
#      12 try:
#      13     do_return = True
# ---> 14     retval_ = ag__.converted_call(ag__.ld(seg_loss), (ag__.ld(y_true), ag__.ld(y_pred)), None, fscope) + ag__.converted_call(ag__.ld(denoise_loss), (ag__.ld(y_true), ag__.ld(y_pred)), None, fscope)
#      15 except:
#      16     do_return = False
#
# File /tmp/__autograph_generated_file0m4urem7.py:14, in outer_factory.<locals>.inner_factory.<locals>.tf__seg_loss(y_true, y_pred)
#      12 retval_ = ag__.UndefinedReturnValue()
#      13 (targets, masks, bg, fg, b) = ag__.converted_call(ag__.ld(split_y_true), (ag__.ld(y_true), ag__.ld(n_chan)), None, fscope)
# ---> 14 (denoiseds, pred_bg, pred_fg, pred_b) = ag__.converted_call(ag__.ld(split_y_pred), (ag__.ld(y_pred), ag__.ld(n_chan)), None, fscope)
#      15 assert ag__.and_(lambda : ag__.converted_call(ag__.ld(len), (ag__.ld(denoiseds),), None, fscope) == ag__.converted_call(ag__.ld(len), (ag__.ld(targets),), None, fscope), lambda : ag__.converted_call(ag__.ld(len), (ag__.ld(targets),), None, fscope) == ag__.converted_call(ag__.ld(len), (ag__.ld(masks),), None, fscope))
#      16 onehot_gt = ag__.converted_call(ag__.ld(tf).reshape, (ag__.converted_call(ag__.ld(tf).stack, ([ag__.ld(bg), ag__.ld(fg), ag__.ld(b)],), dict(axis=-1), fscope), [-1, 3]), None, fscope)
#
# File /tmp/__autograph_generated_filerp39t8qu.py:10, in outer_factory.<locals>.inner_factory.<locals>.tf__split_y_pred(y_pred, n_chan)
#       8 do_return = False
#       9 retval_ = ag__.UndefinedReturnValue()
# ---> 10 splits = ag__.converted_call(ag__.ld(tf).split, (ag__.ld(y_pred), ag__.ld(n_chan) + 3), dict(axis=ag__.converted_call(ag__.ld(len), (ag__.ld(y_pred).shape,), None, fscope) - 1), fscope)
#      11 (pred_bg, pred_fg, pred_b) = ag__.ld(splits)[-3:]
#      12 denoiseds = ag__.ld(splits)[:-3]
#
# ValueError: in user code:
#
#     File "/home/aleksandra/SSD/miniconda3/envs/denoiseg/lib/python3.9/site-packages/keras/engine/training.py", line 1284, in train_function  *
#         return step_function(self, iterator)
#     File "/home/aleksandra/SSD/vscode/DenoiSeg/denoiseg/internals/losses.py", line 44, in denoiseg  *
#         return seg_loss(y_true, y_pred) + denoise_loss(y_true, y_pred)
#     File "/home/aleksandra/SSD/vscode/DenoiSeg/denoiseg/internals/losses.py", line 55, in seg_loss  *
#         denoiseds, pred_bg, pred_fg, pred_b = split_y_pred(y_pred, n_chan)
#     File "/home/aleksandra/SSD/vscode/DenoiSeg/denoiseg/internals/losses.py", line 105, in split_y_pred  *
#         splits = tf.split(y_pred, n_chan + 3, axis=len(y_pred.shape) - 1)
#
#     ValueError: Dimension size must be evenly divisible by 4 but is 5
#     	Number of ways to split should evenly divide the split dimension for '{{node denoiseg/split_1}} = Split[T=DT_FLOAT, num_split=4](denoiseg/split_1/split_dim, model/conv2d/BiasAdd)' with input shapes: [], [?,?,?,5] and with computed input tensors: input[0] = <3>.

# %%
history.history.keys()

# %%
plot_history(history, ['loss', 'val_loss'])

# %% [markdown]
# ## Computing Threshold Value
# The network predicts 4 output channels:
# 1. The denoised input.
# 2. The foreground likelihoods.
# 3. The background likelihoods.
# 4. The border likelihoods.
#
# We will threshold the foreground prediction image to obtain object segmentations. The optimal threshold is determined on the validation data. Additionally we can optimize the threshold for a given measure. In this case we choose the Average Precision (AP) measure.

# %%
threshold, val_score = model.optimize_thresholds(val_images[:len(available_val_masks)], val_masks, measure=measure_precision(), axes='YX')

print("The higest score of {} is achieved with threshold = {}.".format(np.round(val_score, 3), threshold))

# %% [markdown]
# ## Test Data
# Finally we load the test data and run the prediction.

# %%
denoised_images = []
segmented_images = []

for i in range(test_images.shape[0]):
    predicted_channels = model.predict(test_images[i].astype(np.float32), axes='YX')
    denoised_images.append(predicted_channels[...,0])
    segmented_images.append(compute_labels(predicted_channels, threshold))

# %% [markdown]
# ### Visualize the results

# %%
sl = 6
fig = plt.figure()
plt.figure(figsize=(20,10))
plt.subplot(1, 4, 1)
plt.imshow(test_images[sl])
plt.title("Raw image")

plt.subplot(1, 4, 2)
plt.imshow(denoised_images[sl])
plt.title("Predicted denoised image")

plt.subplot(1, 4, 3)
plt.imshow(segmented_images[sl], cmap = "viridis")
plt.title("Predicted segmentation")

plt.show()

# %% [markdown]
# ### Export your model for Fiji

# %%
model.export_TF(name='DenoiSeg - YourOwnData Example', 
                description='This is the 2D DenoiSeg example trained on YourOwnData in python.', 
                authors=["You"],
                test_img=X_val[0,...,0], axes='YX',
                patch_shape=(128, 128))
